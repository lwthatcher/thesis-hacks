# %%
import numpy as np
import matplotlib.pyplot as plt

# config  params
FILE = 'data/pills-s0.npy'
X = np.load(FILE)

H = [np.histogram(X[:,i], bins='auto') for i in range(X.shape[1])]
for h in H:
    print(h[1].shape)

fig = plt.figure()
ax1 = fig.add_subplot(231)
ax1.hist(X[:,0], bins='auto')
ax1 = fig.add_subplot(232)
ax1.hist(X[:,1], bins='auto')
ax1 = fig.add_subplot(233)
ax1.hist(X[:,2], bins='auto')
ax1 = fig.add_subplot(234)
ax1.hist(X[:,3], bins='auto')
ax1 = fig.add_subplot(235)
ax1.hist(X[:,4], bins='auto')
ax1 = fig.add_subplot(236)
ax1.hist(X[:,5], bins='auto')
plt.show()
# Out:
# (407,)
# (109,)
# (463,)
# (1716,)
# (810,)
# (600,)
